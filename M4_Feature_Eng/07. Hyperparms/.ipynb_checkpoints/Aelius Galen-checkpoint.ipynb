# %%
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sb
import sklearn as skl
import time
from IPython.display import display, clear_output

import sklearn
from sklearn import pipeline      # Pipeline
from sklearn import preprocessing # OrdinalEncoder, LabelEncoder
from sklearn import impute
from sklearn import compose
from sklearn import model_selection # train_test_split
from sklearn import metrics         # accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import set_config

set_config(display='diagram') # Useful for display the pipeline

print("Pandas  ", pd.__version__)
print("Sklearn ", skl.__version__) # Try to use 0.24
# Out:
# Pandas   1.1.3
# Sklearn  0.24.2

# %% [markdown]
# **Aelius Galen**

# %%
df   = pd.read_csv("heart.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
df.hist( figsize=(16,8));

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
import numpy as np
age=df['age']
sex=df['sex']
cp=df['cp']
trestbps=df['trestbps']
chol=df['chol']
fbs=df['fbs']
restecg=df['restecg']
thalach=df['thalach']
exang=df['exang']
oldpeak=df['oldpeak']
slope=df['slope']
ca=df['ca']
thal=df['thal']
target=df['target']


age_s=np.std(age)

#sex_s=np.std(sex)

cp_s=np.std(cp)
trestbps_s=np.std(trestbps)
chol_s=np.std(chol)
fbs_s=np.std(fbs)
restecg_s=np.std(restecg)
thalach_s=np.std(thalach)
exang_s=np.std(exang)
oldpeak_s=np.std(oldpeak)
slope_s=np.std(slope)
ca_s=np.std(ca)
thal_s=np.std(thal)

#target_s=np.std(target)

# %%
for _ in range(10):

    for _,row in df.iterrows():
        temp={
            "age": row['age']+np.random.uniform(age_s),
            "sex": round(row['sex']+np.random.uniform(sex_s),0),
            "cp": row['cp']+np.random.uniform(cp_s),
            "trestbps": row['trestbps']+np.random.uniform(trestbps_s),
            "chol": row['chol']+np.random.uniform(chol_s),
            "fbs": row['fbs']+np.random.uniform(fbs_s),
            "restecg": row['restecg']+np.random.uniform(restecg_s),
            "thalach": row['thalach']+np.random.uniform(thalach_s),
            "exang": row['exang']+np.random.uniform(exang_s),
            "oldpeak": row['oldpeak']+np.random.uniform(oldpeak_s),
            "slope": row['slope']+np.random.uniform(oldpeak_s),
            "ca": row['ca']+np.random.uniform(ca_s),
            "thal": row['thal']+np.random.uniform(thal_s),
            
        }
        dataset.append(temp)

# %%
dataset=[]

for _ in range(10):

    for _,row in df.iterrows():
        temp={
            "age": row['age']+np.random.uniform(age_s),
            
            #"sex": round(row['sex']+np.random.uniform(sex_s),0),
            "sex": row['sex']+np.random.randint(0,1),
            
            "cp": row['cp']+np.random.uniform(cp_s),
            "trestbps": row['trestbps']+np.random.uniform(trestbps_s),
            "chol": row['chol']+np.random.uniform(chol_s),
            "fbs": row['fbs']+np.random.uniform(fbs_s),
            "restecg": row['restecg']+np.random.uniform(restecg_s),
            "thalach": row['thalach']+np.random.uniform(thalach_s),
            "exang": row['exang']+np.random.uniform(exang_s),
            "oldpeak": row['oldpeak']+np.random.uniform(oldpeak_s),
            "slope": row['slope']+np.random.uniform(oldpeak_s),
            "ca": row['ca']+np.random.uniform(ca_s),
            "thal": row['thal']+np.random.uniform(thal_s),
            "target": round(row['target']+np.random.uniform(target_s),0),
            "target": row['target']+np.random.randint(0,1),
            #"target": round(row['target']+np.random.uniform(target_s),0) #rounded
            

        }
        dataset.append(temp)
        

print(len(dataset),"augmented data created.")
df_au=pd.DataFrame(dataset)
df_au
# Out:
# 3030 augmented data created.
#             age  sex        cp    trestbps        chol       fbs   restecg  \
# 0     65.810406  1.0  4.010172  156.853602  241.280703  1.369654  0.749316
# 1     45.063674  1.0  3.006151  145.830888  286.873601  0.513925  1.892778
# 2     42.210221  0.0  2.009044  139.903537  209.562839  0.561592  0.597536
# 3     60.026354  1.0  2.004014  124.007098  279.616949  0.434128  1.609216
# 4     59.325988  0.0  1.020205  132.744195  399.398021  0.428234  1.754397
# ...         ...  ...       ...         ...         ...       ...       ...
# 3025  58.212721  0.0  1.017564  151.783901  253.161842  0.360322  1.856822
# 3026  53.174783  1.0  4.020273  111.373710  293.897336  0.400677  1.755876
# 3027  70.588570  1.0  1.006886  148.084985  241.620674  1.729345  1.541724
# 3028  61.523815  1.0  1.025643  140.545447  174.997847  0.930319  1.648533
# 3029  62.252302  0.0  2.019618  143.905975  270.271652  0.863341  0.771515
#
#          thalach     exang   oldpeak     slope        ca      thal  target
# 0     171.489546  0.474349  3.454536  1.148222  1.019215  1.862245     1.0
# 1     204.625008  0.936569  4.567217  1.145686  1.011416  2.855761     1.0
# 2     179.844749  0.571242  2.540457  3.041008  1.019487  2.959043     1.0
# 3     191.217237  0.740960  1.890866  3.033731  1.008576  2.846372     1.0
# 4     174.229441  1.837636  1.601592  3.118890  1.010095  2.819228     1.0
# ...          ...       ...       ...       ...       ...       ...     ...
# 3025  142.011838  1.989569  1.236870  2.071842  1.009345  3.803430     0.0
# 3026  150.360291  0.577124  2.338995  2.095230  1.017046  3.770414     0.0
# 3027  163.694454  0.548354  4.506137  2.049857  3.016480  3.620760     0.0
# 3028  126.475172  1.654425  2.226241  2.157765  2.008250  3.675818     0.0
# 3029  193.664720  0.691011  1.121313  2.144983  2.020321  2.962017     0.0
#
# [3030 rows x 14 columns]

# %%
df_au.hist( figsize=(16,8));

# %%
# Out:
#             age  sex        cp    trestbps        chol       fbs   restecg  \
# 0     67.169227  2.0  4.016377  150.455529  279.966675  1.385823  0.791644
# 1     39.930071  2.0  3.027573  141.723542  268.175778  0.377358  1.601607
# 2     45.945955  1.0  2.017859  147.050113  229.481787  0.421404  0.929539
# 3     62.925917  2.0  2.002725  133.815879  246.873474  0.831090  1.723185
# 4     63.253389  1.0  1.023478  133.478347  386.534661  0.858619  1.574756
# ...         ...  ...       ...         ...         ...       ...       ...
# 1813  64.804846  1.0  1.021286  149.317463  261.827979  0.917670  1.836661
# 1814  48.865905  2.0  4.016773  113.420768  272.298847  0.782858  1.566514
# 1815  72.420793  2.0  1.013631  149.424731  214.030064  1.826990  1.774725
# 1816  64.555253  2.0  1.006718  139.170814  162.706961  0.726114  1.825655
# 1817  60.153545  1.0  2.006257  144.617455  252.661315  0.491162  0.527254
#
#          thalach     exang   oldpeak     slope        ca      thal    target
# 0     164.554215  0.794103  3.455529  1.066926  1.009409  1.949961  1.916907
# 1     193.478809  0.540587  4.575601  1.058987  1.003641  2.804441  1.960970
# 2     178.320743  0.751675  2.426414  3.040254  1.000119  2.884654  1.855963
# 3     192.645294  0.893308  1.936432  3.097519  1.015324  2.899508  1.554295
# 4     176.316623  1.748626  1.635317  3.061644  1.000436  2.684452  1.579414
# ...          ...       ...       ...       ...       ...       ...       ...
# 1813  141.044443  1.936145  1.208680  2.040383  1.007760  3.725232  0.587894
# 1814  139.301370  0.498143  2.211301  2.099879  1.004879  3.773588  0.998449
# 1815  157.010684  0.875477  4.499245  2.129612  3.008424  3.635364  0.919662
# 1816  131.590720  1.870714  2.222102  2.061229  2.020293  3.971655  0.923412
# 1817  192.423068  0.664104  1.046945  2.099347  2.006675  2.749035  0.594104
#
# [1818 rows x 14 columns]

# %%
print(dataset)
# Out:
# [     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns], {'age': 68.49102334329221, 'sex': 1.0, 'cp': 4.003551333657271, 'trestbps': 149.79520377935202, 'chol': 254.244421433806, 'fbs': 1.9040317605234374, 'restecg': 0.6883149702576514, 'thalach': 162.79568349142332, 'exang': 0.8713344923531093, 'oldpeak': 3.438142001573117, 'slope': 1.0604755887831672, 'ca': 1.0146065300751643, 'thal': 1.7446312347618576, 'target': 1.9917121028090994}, {'age': 42.2223028220621, 'sex': 2.0, 'cp': 3.003963542932472, 'trestbps': 139.0671336031496, 'chol': 281.14268841053376, 'fbs': 0.8972504803743647, 'restecg': 1.861970927151835, 'thalach': 205.73350375767043, 'exang': 0.605749676617424, 'oldpeak': 4.6090359789679916, 'slope': 1.0960518813278148, 'ca': 1.007887184692784, 'thal': 2.6964059929162176, 'target': 1.699956737183047}, {'age': 47.668792232087725, 'sex': 1.0, 'cp': 2.0062261903745457, 'trestbps': 144.6379196421135, 'chol': 220.50912898043168, 'fbs': 0.9805398953301633, 'restecg': 0.7923026456370925, 'thalach': 178.74342286829602, 'exang': 0.4937551656276329, 'oldpeak': 2.429992238811728, 'slope': 3.044816677091407, 'ca': 1.007037651965461, 'thal': 2.684752135858419, 'target': 1.8077859618041332}, {'age': 59.769071910923216, 'sex': 2.0, 'cp': 2.01613146597887, 'trestbps': 130.51304427372432, 'chol': 248.40799259509066, 'fbs': 0.92308013326906, 'restecg': 1.9651895035005333, 'thalach': 199.41527162713643, 'exang': 0.5037286523494435, 'oldpeak': 1.8601888797634563, 'slope': 3.062380095091595, 'ca': 1.000939417297174, 'thal': 2.8313060771435916, 'target': 1.9828932270083282}, {'age': 64.53765867005946, 'sex': 1.0, 'cp': 1.0298563346224965, 'trestbps': 128.93738739581948, 'chol': 386.1109045808206, 'fbs': 0.9882639214247546, 'restecg': 1.8499142684985357, 'thalach': 169.20693416483303, 'exang': 1.8280302090680558, 'oldpeak': 1.7190450914568611, 'slope': 3.1181815099125085, 'ca': 1.013983311529791, 'thal': 2.834529240411711, 'target': 1.606018189163103}, {'age': 58.13680827246354, 'sex': 2.0, 'cp': 1.017196758812052, 'trestbps': 142.19302551062208, 'chol': 224.51808954452954, 'fbs': 0.5472372978468206, 'restecg': 1.7389651489039892, 'thalach': 163.7058236305641, 'exang': 0.5734278882164409, 'oldpeak': 1.4265875684143845, 'slope': 2.1137858115611863, 'ca': 1.0014648968667932, 'thal': 1.8841488113230305, 'target': 1.549859453658686}, {'age': 58.511262027814354, 'sex': 1.0, 'cp': 2.0232998826470947, 'trestbps': 141.9425868036443, 'chol': 321.7326559554103, 'fbs': 0.36394088612838077, 'restecg': 0.7994612724834094, 'thalach': 165.86022510477247, 'exang': 0.6322798987590657, 'oldpeak': 2.4286109778260068, 'slope': 2.0608395854763333, 'ca': 1.0187802100439893, 'thal': 2.7310605679813182, 'target': 1.5857233502593329}, {'age': 50.23038916543779, 'sex': 2.0, 'cp': 2.000950826738914, 'trestbps': 130.1030449515632, 'chol': 296.5480622922625, 'fbs': 0.9123939762368696, 'restecg': 1.8981868313115642, 'thalach': 174.26635171435612, 'exang': 0.7972518293172678, 'oldpeak': 1.1028441002233225, 'slope': 3.0177043136461594, 'ca': 1.0018759076985262, 'thal': 3.959565182573572, 'target': 1.705945261348471}, {'age': 58.47623409612627, 'sex': 2.0, 'cp': 3.021204431156491, 'trestbps': 181.25767087225216, 'chol': 250.32938462451168, 'fbs': 1.7761667720831018, 'restecg': 1.5872308548146161, 'thalach': 169.30571985514385, 'exang': 0.5912080993229518, 'oldpeak': 1.636895778593028, 'slope': 3.135519510800341, 'ca': 1.0092927700565848, 'thal': 3.931392037634057, 'target': 1.5621294514657085}, {'age': 59.69404526365907, 'sex': 2.0, 'cp': 3.0186223266796866, 'trestbps': 166.2351554226964, 'chol': 178.47101189822445, 'fbs': 0.47990275289849227, 'restecg': 1.8497799429294626, 'thalach': 177.46686575088646, 'exang': 0.9393398393402929, 'oldpeak': 2.671741550149176, 'slope': 3.049230724309003, 'ca': 1.0138393237006351, 'thal': 2.8490710107715955, 'target': 1.9423372538885986}, {'age': 56.699264157277895, 'sex': 2.0, 'cp': 1.0241168870825326, 'trestbps': 151.15958649698254, 'chol': 264.13901276440123, 'fbs':  ...
